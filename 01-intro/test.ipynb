# %%
import openai

# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv
from pathlib import Path
dotenv_path = Path().resolve().parent / ".env"
load_dotenv(dotenv_path)
# Out:
# True

# %%
client = OpenAI()

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[{"role": "user", "content": "is it too late to join the course?"}]
)

# %%
response.choices[0].message.content
# Out:
# "I'm sorry, but I would need more information to answer your question accurately. Could you please provide more details about the course you're interested in? For example, the start date, registration deadline, and any specific requirements or prerequisites? This information will help in determining whether it's too late for you to join."
